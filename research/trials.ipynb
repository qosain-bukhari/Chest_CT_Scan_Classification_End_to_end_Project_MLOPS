# %%
# Import required libraries
import gdown
from pathlib import Path
import os

# Google Drive URL
url = "https://drive.google.com/uc?export=download&id=1z0mreUtRmR-P-magILsDR3T7M6IkGXtY"

# Target directory
data_dir = Path("data")
os.makedirs(data_dir, exist_ok=True)

# Output ZIP file path
output = data_dir / "chest_ct_scan.zip"

# Download the ZIP file
gdown.download(url, str(output), quiet=False)

print(f"ZIP file downloaded to: {output}")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1z0mreUtRmR-P-magILsDR3T7M6IkGXtY
# From (redirected): https://drive.google.com/uc?export=download&id=1z0mreUtRmR-P-magILsDR3T7M6IkGXtY&confirm=t&uuid=ac8fc12e-115e-4bf8-a881-c8fbe0b1c499
# To: d:\Data Science\project Series\Chest_Cancer_Classification_DL\research\data\chest_ct_scan.zip
# 100%|██████████| 49.0M/49.0M [00:21<00:00, 2.28MB/s]
# ZIP file downloaded to: data\chest_ct_scan.zip
